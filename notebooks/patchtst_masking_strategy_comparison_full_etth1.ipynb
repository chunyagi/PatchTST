# %% [markdown]
# # Full Training: Masking Strategy Evaluation on ETTh1
#
# This notebook conducts full-scale pretraining experiments (100 epochs) to further validate the Gaussian noise masking method, following the initial validation in `patchtst_masking_strategy_comparison.ipynb`. Additionally, we evaluate the few-shot learning capability by using only 10% of training data.

# %% [markdown]
# ## 0. Get Setup

# %%
# Clone the github repo and download dependencies
# !git clone https://github.com/chunyagi/PatchTST.git
# Out:
# Cloning into 'PatchTST'...

# %%
# Install dependencies (uncomment it if you're not using google colab)
# !pip install -r PatchTST/PatchTST_supervised/requirements.txt

# %%
# Traverse into the target directory
# %cd /content/PatchTST/PatchTST_self_supervised

# %% [markdown]
# ## 1. Download Data

# %%
# Download data from google drive with gdown
try:
    import gdown
    print(f"[INFO] gdown version: {gdown.__version__}")
except:
    print("[INFO] Couldn't find gdown, installing it...")
    # !pip install -q gdown
    import gdown
    print(f"[INFO] gdown version: {gdown.__version__}")

# !mkdir -p /data/datasets/public/ETDataset/ETT-small
# !gdown 1vOClm_t4RgUf8nqherpTfNnB8rrYq14Q -O /data/datasets/public/ETDataset/ETT-small/
# Out:
# [INFO] gdown version: 5.2.1
# Downloading...
# From: https://drive.google.com/uc?id=1vOClm_t4RgUf8nqherpTfNnB8rrYq14Q
# To: /data/datasets/public/ETDataset/ETT-small/ETTh1.csv
# 100% 2.59M/2.59M [00:00<00:00, 17.3MB/s]

# %% [markdown]
# ## 2. Zero Masking (Baseline)
#
# This is the baseline masking strategy from the original PatchTST paper. It randomly selects patches and replaces their values with zeros.

# %% [markdown]
# ### 2.1 Pre-training

# %%
# !python patchtst_pretrain.py --dset etth1 --n_heads 4 --d_model 16 --d_ff 128 --n_epochs_pretrain 100 --pretrained_model_id 1 --seed 2019
# !python patchtst_pretrain.py --dset etth1 --n_heads 4 --d_model 16 --d_ff 128 --n_epochs_pretrain 100 --pretrained_model_id 2 --seed 2020
# !python patchtst_pretrain.py --dset etth1 --n_heads 4 --d_model 16 --d_ff 128 --n_epochs_pretrain 100 --pretrained_model_id 3 --seed 2021
# !python patchtst_pretrain.py --dset etth1 --n_heads 4 --d_model 16 --d_ff 128 --n_epochs_pretrain 100 --pretrained_model_id 4 --seed 2022
# !python patchtst_pretrain.py --dset etth1 --n_heads 4 --d_model 16 --d_ff 128 --n_epochs_pretrain 100 --pretrained_model_id 5 --seed 2023
# Out:
# args: Namespace(dset_pretrain='etth1', context_points=512, target_points=96, batch_size=64, num_workers=0, scaler='standard', features='M', percent=100, patch_len=12, stride=12, revin=1, n_layers=3, n_heads=4, d_model=16, d_ff=128, dropout=0.2, head_dropout=0.2, mask_ratio=0.4, use_gaussian_noise=0, noise_std=0.1, n_epochs_pretrain=100, lr=0.0001, pretrained_model_id=1, model_type='based_model', seed=2019)
# number of patches: 42
# number of model params 17260
# suggested_lr 0.0015922827933410938
# number of patches: 42
# number of model params 17260
#           epoch     train_loss     valid_loss           time
# Better model found at epoch 0 with valid_loss value: 0.9851055809582585.
#               0       1.057962       0.985106          00:01
# Better model found at epoch 1 with valid_loss value: 0.9761597775471275.
#               1       1.014445       0.976160          00:01
# Better model found at epoch 2 with valid_loss value: 0.9640895001122083.
# ...

# %% [markdown]
# ### 2.2 Fine-tuning

# %% [markdown]
# #### 2.2.1 Horizon 96

# %%
# !python patchtst_finetune.py --dset etth1 --n_heads 4 --d_model 16 --d_ff 128 --pretrained_model ./saved_models/etth1/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_zero_model1.pth --is_finetune 1 --finetuned_model_id 1 --seed 2019
# !python patchtst_finetune.py --dset etth1 --n_heads 4 --d_model 16 --d_ff 128 --pretrained_model ./saved_models/etth1/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_zero_model2.pth --is_finetune 1 --finetuned_model_id 2 --seed 2020
# !python patchtst_finetune.py --dset etth1 --n_heads 4 --d_model 16 --d_ff 128 --pretrained_model ./saved_models/etth1/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_zero_model3.pth --is_finetune 1 --finetuned_model_id 3 --seed 2021
# !python patchtst_finetune.py --dset etth1 --n_heads 4 --d_model 16 --d_ff 128 --pretrained_model ./saved_models/etth1/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_zero_model4.pth --is_finetune 1 --finetuned_model_id 4 --seed 2022
# !python patchtst_finetune.py --dset etth1 --n_heads 4 --d_model 16 --d_ff 128 --pretrained_model ./saved_models/etth1/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_zero_model5.pth --is_finetune 1 --finetuned_model_id 5 --seed 2023
# Out:
# args: Namespace(is_finetune=1, is_linear_probe=0, dset_finetune='etth1', context_points=512, target_points=96, batch_size=64, num_workers=0, scaler='standard', features='M', percent=100, patch_len=12, stride=12, revin=1, affine=0, n_layers=3, n_heads=4, d_model=16, d_ff=128, dropout=0.2, head_dropout=0.2, n_epochs_finetune=20, lr=0.0001, pretrained_model='./saved_models/etth1/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_zero_model1.pth', finetuned_model_id=1, model_type='based_model', seed=2019)
# number of patches: 42
# number of model params 81664
# weights from ./saved_models/etth1/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_zero_model1.pth successfully transferred!
#
# suggested_lr 0.001917910261672489
# end-to-end finetuning
# number of patches: 42
# number of model params 81664
# ...

# %%
# Evaluate the results
import numpy as np
scores_mse = np.array([0.37980026, 0.38196558, 0.37782618, 0.3811843, 0.3781326])
scores_mae = np.array([0.40929615, 0.40970063, 0.40524143, 0.4091849, 0.40836868])

print(f'MSE: {np.mean(scores_mse):.3f} ± {np.std(scores_mse):.3f} | MAE: {np.mean(scores_mae):.3f} ± {np.std(scores_mae):.3f}')
# Out:
# MSE: 0.380 ± 0.002 | MAE: 0.408 ± 0.002

# %% [markdown]
# #### 2.2.2 Horizon 192

# %%
# !python patchtst_finetune.py --dset etth1 --target_points 192 --n_heads 4 --d_model 16 --d_ff 128 --pretrained_model ./saved_models/etth1/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_zero_model1.pth --is_finetune 1 --finetuned_model_id 1 --seed 2019
# !python patchtst_finetune.py --dset etth1 --target_points 192 --n_heads 4 --d_model 16 --d_ff 128 --pretrained_model ./saved_models/etth1/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_zero_model2.pth --is_finetune 1 --finetuned_model_id 2 --seed 2020
# !python patchtst_finetune.py --dset etth1 --target_points 192 --n_heads 4 --d_model 16 --d_ff 128 --pretrained_model ./saved_models/etth1/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_zero_model3.pth --is_finetune 1 --finetuned_model_id 3 --seed 2021
# !python patchtst_finetune.py --dset etth1 --target_points 192 --n_heads 4 --d_model 16 --d_ff 128 --pretrained_model ./saved_models/etth1/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_zero_model4.pth --is_finetune 1 --finetuned_model_id 4 --seed 2022
# !python patchtst_finetune.py --dset etth1 --target_points 192 --n_heads 4 --d_model 16 --d_ff 128 --pretrained_model ./saved_models/etth1/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_zero_model5.pth --is_finetune 1 --finetuned_model_id 5 --seed 2023
# Out:
# args: Namespace(is_finetune=1, is_linear_probe=0, dset_finetune='etth1', context_points=512, target_points=192, batch_size=64, num_workers=0, scaler='standard', features='M', percent=100, patch_len=12, stride=12, revin=1, affine=0, n_layers=3, n_heads=4, d_model=16, d_ff=128, dropout=0.2, head_dropout=0.2, n_epochs_finetune=20, lr=0.0001, pretrained_model='./saved_models/etth1/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_zero_model1.pth', finetuned_model_id=1, model_type='based_model', seed=2019)
# number of patches: 42
# number of model params 146272
# weights from ./saved_models/etth1/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_zero_model1.pth successfully transferred!
#
# suggested_lr 0.0013219411484660286
# end-to-end finetuning
# number of patches: 42
# number of model params 146272
# ...

# %%
# Evaluate the results
scores_mse = np.array([0.41112816, 0.4109433, 0.42980835, 0.41310242, 0.41780955])
scores_mae = np.array([0.428413, 0.4263027, 0.43628827, 0.42631269, 0.43114865])

print(f'MSE: {np.mean(scores_mse):.3f} ± {np.std(scores_mse):.3f} | MAE: {np.mean(scores_mae):.3f} ± {np.std(scores_mae):.3f}')
# Out:
# MSE: 0.417 ± 0.007 | MAE: 0.430 ± 0.004

# %% [markdown]
# #### 2.2.3 Horizon 336

# %%
# !python patchtst_finetune.py --dset etth1 --target_points 336 --n_heads 4 --d_model 16 --d_ff 128 --pretrained_model ./saved_models/etth1/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_zero_model1.pth --is_finetune 1 --finetuned_model_id 1 --seed 2019
# !python patchtst_finetune.py --dset etth1 --target_points 336 --n_heads 4 --d_model 16 --d_ff 128 --pretrained_model ./saved_models/etth1/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_zero_model2.pth --is_finetune 1 --finetuned_model_id 2 --seed 2020
# !python patchtst_finetune.py --dset etth1 --target_points 336 --n_heads 4 --d_model 16 --d_ff 128 --pretrained_model ./saved_models/etth1/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_zero_model3.pth --is_finetune 1 --finetuned_model_id 3 --seed 2021
# !python patchtst_finetune.py --dset etth1 --target_points 336 --n_heads 4 --d_model 16 --d_ff 128 --pretrained_model ./saved_models/etth1/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_zero_model4.pth --is_finetune 1 --finetuned_model_id 4 --seed 2022
# !python patchtst_finetune.py --dset etth1 --target_points 336 --n_heads 4 --d_model 16 --d_ff 128 --pretrained_model ./saved_models/etth1/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_zero_model5.pth --is_finetune 1 --finetuned_model_id 5 --seed 2023
# Out:
# args: Namespace(is_finetune=1, is_linear_probe=0, dset_finetune='etth1', context_points=512, target_points=336, batch_size=64, num_workers=0, scaler='standard', features='M', percent=100, patch_len=12, stride=12, revin=1, affine=0, n_layers=3, n_heads=4, d_model=16, d_ff=128, dropout=0.2, head_dropout=0.2, n_epochs_finetune=20, lr=0.0001, pretrained_model='./saved_models/etth1/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_zero_model1.pth', finetuned_model_id=1, model_type='based_model', seed=2019)
# number of patches: 42
# number of model params 243184
# weights from ./saved_models/etth1/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_zero_model1.pth successfully transferred!
#
# suggested_lr 0.0006280291441834253
# end-to-end finetuning
# number of patches: 42
# number of model params 243184
# ...

# %%
# Evaluate the results
scores_mse = np.array([0.42914817, 0.42853728, 0.44394827, 0.43228152, 0.43695897])
scores_mae = np.array([0.44135535, 0.44107535, 0.44580197, 0.44041723, 0.44488567])

print(f'MSE: {np.mean(scores_mse):.3f} ± {np.std(scores_mse):.3f} | MAE: {np.mean(scores_mae):.3f} ± {np.std(scores_mae):.3f}')
# Out:
# MSE: 0.434 ± 0.006 | MAE: 0.443 ± 0.002

# %% [markdown]
# #### 2.2.4 Horizon 720

# %%
# !python patchtst_finetune.py --dset etth1 --target_points 720 --n_heads 4 --d_model 16 --d_ff 128 --pretrained_model ./saved_models/etth1/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_zero_model1.pth --is_finetune 1 --finetuned_model_id 1 --seed 2019
# !python patchtst_finetune.py --dset etth1 --target_points 720 --n_heads 4 --d_model 16 --d_ff 128 --pretrained_model ./saved_models/etth1/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_zero_model2.pth --is_finetune 1 --finetuned_model_id 2 --seed 2020
# !python patchtst_finetune.py --dset etth1 --target_points 720 --n_heads 4 --d_model 16 --d_ff 128 --pretrained_model ./saved_models/etth1/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_zero_model3.pth --is_finetune 1 --finetuned_model_id 3 --seed 2021
# !python patchtst_finetune.py --dset etth1 --target_points 720 --n_heads 4 --d_model 16 --d_ff 128 --pretrained_model ./saved_models/etth1/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_zero_model4.pth --is_finetune 1 --finetuned_model_id 4 --seed 2022
# !python patchtst_finetune.py --dset etth1 --target_points 720 --n_heads 4 --d_model 16 --d_ff 128 --pretrained_model ./saved_models/etth1/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_zero_model5.pth --is_finetune 1 --finetuned_model_id 5 --seed 2023
# Out:
# args: Namespace(is_finetune=1, is_linear_probe=0, dset_finetune='etth1', context_points=512, target_points=720, batch_size=64, num_workers=0, scaler='standard', features='M', percent=100, patch_len=12, stride=12, revin=1, affine=0, n_layers=3, n_heads=4, d_model=16, d_ff=128, dropout=0.2, head_dropout=0.2, n_epochs_finetune=20, lr=0.0001, pretrained_model='./saved_models/etth1/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_zero_model1.pth', finetuned_model_id=1, model_type='based_model', seed=2019)
# number of patches: 42
# number of model params 501616
# weights from ./saved_models/etth1/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_zero_model1.pth successfully transferred!
#
# suggested_lr 0.0010974987654930567
# end-to-end finetuning
# number of patches: 42
# number of model params 501616
# ...

# %%
# Evaluate the results
scores_mse = np.array([0.47807503, 0.46582302, 0.5060047, 0.48247394, 0.46756145])
scores_mae = np.array([0.47945762, 0.4712315, 0.48488447, 0.47923544, 0.47404012])

print(f'MSE: {np.mean(scores_mse):.3f} ± {np.std(scores_mse):.3f} | MAE: {np.mean(scores_mae):.3f} ± {np.std(scores_mae):.3f}')
# Out:
# MSE: 0.480 ± 0.014 | MAE: 0.478 ± 0.005

# %% [markdown]
# ## 3. Gaussian Noise Addition
#
# Unlike zero masking which completely removes information, Gaussian noise masking adds stochastic perturbations to the original signal:
# $x_\text{masked} = x_\text{original} + \epsilon$, where $\epsilon \sim N(0, \sigma^2)$.
#
# **Note:** We'll use σ = 0.1 as it achieves the best performance in the quick experiments (10 pre-training epochs).

# %% [markdown]
# ### 3.1 Pre-training

# %%
# !python patchtst_pretrain.py --dset etth1 --n_heads 4 --d_model 16 --d_ff 128 --use_gaussian_noise 1 --noise_std 0.1 --n_epochs_pretrain 100 --pretrained_model_id 1 --seed 2019
# !python patchtst_pretrain.py --dset etth1 --n_heads 4 --d_model 16 --d_ff 128 --use_gaussian_noise 1 --noise_std 0.1 --n_epochs_pretrain 100 --pretrained_model_id 2 --seed 2020
# !python patchtst_pretrain.py --dset etth1 --n_heads 4 --d_model 16 --d_ff 128 --use_gaussian_noise 1 --noise_std 0.1 --n_epochs_pretrain 100 --pretrained_model_id 3 --seed 2021
# !python patchtst_pretrain.py --dset etth1 --n_heads 4 --d_model 16 --d_ff 128 --use_gaussian_noise 1 --noise_std 0.1 --n_epochs_pretrain 100 --pretrained_model_id 4 --seed 2022
# !python patchtst_pretrain.py --dset etth1 --n_heads 4 --d_model 16 --d_ff 128 --use_gaussian_noise 1 --noise_std 0.1 --n_epochs_pretrain 100 --pretrained_model_id 5 --seed 2023
# Out:
# args: Namespace(dset_pretrain='etth1', context_points=512, target_points=96, batch_size=64, num_workers=0, scaler='standard', features='M', percent=100, patch_len=12, stride=12, revin=1, n_layers=3, n_heads=4, d_model=16, d_ff=128, dropout=0.2, head_dropout=0.2, mask_ratio=0.4, use_gaussian_noise=1, noise_std=0.1, n_epochs_pretrain=100, lr=0.0001, pretrained_model_id=1, model_type='based_model', seed=2019)
# number of patches: 42
# number of model params 17260
# suggested_lr 0.002310129700083158
# number of patches: 42
# number of model params 17260
#           epoch     train_loss     valid_loss           time
# Better model found at epoch 0 with valid_loss value: 0.5918794532652604.
#               0       1.105635       0.591879          00:02
# Better model found at epoch 1 with valid_loss value: 0.387562766494614.
#               1       0.684667       0.387563          00:02
# Better model found at epoch 2 with valid_loss value: 0.2823873139797464.
# ...

# %% [markdown]
# ### 3.2 Fine-tuning

# %% [markdown]
# #### 3.2.1 Horizon 96

# %%
# !python patchtst_finetune.py --dset etth1 --n_heads 4 --d_model 16 --d_ff 128 --pretrained_model ./saved_models/etth1/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_gnoise0.1_model1.pth --is_finetune 1 --finetuned_model_id 1 --seed 2019
# !python patchtst_finetune.py --dset etth1 --n_heads 4 --d_model 16 --d_ff 128 --pretrained_model ./saved_models/etth1/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_gnoise0.1_model2.pth --is_finetune 1 --finetuned_model_id 2 --seed 2020
# !python patchtst_finetune.py --dset etth1 --n_heads 4 --d_model 16 --d_ff 128 --pretrained_model ./saved_models/etth1/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_gnoise0.1_model3.pth --is_finetune 1 --finetuned_model_id 3 --seed 2021
# !python patchtst_finetune.py --dset etth1 --n_heads 4 --d_model 16 --d_ff 128 --pretrained_model ./saved_models/etth1/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_gnoise0.1_model4.pth --is_finetune 1 --finetuned_model_id 4 --seed 2022
# !python patchtst_finetune.py --dset etth1 --n_heads 4 --d_model 16 --d_ff 128 --pretrained_model ./saved_models/etth1/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_gnoise0.1_model5.pth --is_finetune 1 --finetuned_model_id 5 --seed 2023
# Out:
# args: Namespace(is_finetune=1, is_linear_probe=0, dset_finetune='etth1', context_points=512, target_points=96, batch_size=64, num_workers=0, scaler='standard', features='M', percent=100, patch_len=12, stride=12, revin=1, affine=0, n_layers=3, n_heads=4, d_model=16, d_ff=128, dropout=0.2, head_dropout=0.2, n_epochs_finetune=20, lr=0.0001, pretrained_model='./saved_models/etth1/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_gnoise0.1_model1.pth', finetuned_model_id=1, model_type='based_model', seed=2019)
# number of patches: 42
# number of model params 81664
# weights from ./saved_models/etth1/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_gnoise0.1_model1.pth successfully transferred!
#
# suggested_lr 0.0027825594022071257
# end-to-end finetuning
# number of patches: 42
# number of model params 81664
# ...

# %%
scores_mse = np.array([0.36332822, 0.3638639, 0.3660186, 0.3647056, 0.3627568])
scores_mae = np.array([0.3925063, 0.39293417, 0.39470914, 0.3940665, 0.39205942])

print(f'MSE: {np.mean(scores_mse):.3f} ± {np.std(scores_mse):.3f} | MAE: {np.mean(scores_mae):.3f} ± {np.std(scores_mae):.3f}')
# Out:
# MSE: 0.364 ± 0.001 | MAE: 0.393 ± 0.001

# %% [markdown]
# #### 3.2.2 Horizon 192

# %%
# !python patchtst_finetune.py --dset etth1 --target_points 192 --n_heads 4 --d_model 16 --d_ff 128 --pretrained_model ./saved_models/etth1/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_gnoise0.1_model1.pth --is_finetune 1 --finetuned_model_id 1 --seed 2019
# !python patchtst_finetune.py --dset etth1 --target_points 192 --n_heads 4 --d_model 16 --d_ff 128 --pretrained_model ./saved_models/etth1/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_gnoise0.1_model2.pth --is_finetune 1 --finetuned_model_id 2 --seed 2020
# !python patchtst_finetune.py --dset etth1 --target_points 192 --n_heads 4 --d_model 16 --d_ff 128 --pretrained_model ./saved_models/etth1/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_gnoise0.1_model3.pth --is_finetune 1 --finetuned_model_id 3 --seed 2021
# !python patchtst_finetune.py --dset etth1 --target_points 192 --n_heads 4 --d_model 16 --d_ff 128 --pretrained_model ./saved_models/etth1/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_gnoise0.1_model4.pth --is_finetune 1 --finetuned_model_id 4 --seed 2022
# !python patchtst_finetune.py --dset etth1 --target_points 192 --n_heads 4 --d_model 16 --d_ff 128 --pretrained_model ./saved_models/etth1/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_gnoise0.1_model5.pth --is_finetune 1 --finetuned_model_id 5 --seed 2023
# Out:
# args: Namespace(is_finetune=1, is_linear_probe=0, dset_finetune='etth1', context_points=512, target_points=192, batch_size=64, num_workers=0, scaler='standard', features='M', percent=100, patch_len=12, stride=12, revin=1, affine=0, n_layers=3, n_heads=4, d_model=16, d_ff=128, dropout=0.2, head_dropout=0.2, n_epochs_finetune=20, lr=0.0001, pretrained_model='./saved_models/etth1/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_gnoise0.1_model1.pth', finetuned_model_id=1, model_type='based_model', seed=2019)
# number of patches: 42
# number of model params 146272
# weights from ./saved_models/etth1/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_gnoise0.1_model1.pth successfully transferred!
#
# suggested_lr 0.0009111627561154895
# end-to-end finetuning
# number of patches: 42
# number of model params 146272
# ...

# %%
scores_mse = np.array([0.39789826, 0.39668837, 0.4006769, 0.40091062, 0.40018398])
scores_mae = np.array([0.41391695, 0.41239184, 0.4161203, 0.4161972, 0.41596848])

print(f'MSE: {np.mean(scores_mse):.3f} ± {np.std(scores_mse):.3f} | MAE: {np.mean(scores_mae):.3f} ± {np.std(scores_mae):.3f}')
# Out:
# MSE: 0.399 ± 0.002 | MAE: 0.415 ± 0.002

# %% [markdown]
# #### 3.2.3 Horizon 336

# %%
# !python patchtst_finetune.py --dset etth1 --target_points 336 --n_heads 4 --d_model 16 --d_ff 128 --pretrained_model ./saved_models/etth1/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_gnoise0.1_model1.pth --is_finetune 1 --finetuned_model_id 1 --seed 2019
# !python patchtst_finetune.py --dset etth1 --target_points 336 --n_heads 4 --d_model 16 --d_ff 128 --pretrained_model ./saved_models/etth1/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_gnoise0.1_model2.pth --is_finetune 1 --finetuned_model_id 2 --seed 2020
# !python patchtst_finetune.py --dset etth1 --target_points 336 --n_heads 4 --d_model 16 --d_ff 128 --pretrained_model ./saved_models/etth1/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_gnoise0.1_model3.pth --is_finetune 1 --finetuned_model_id 3 --seed 2021
# !python patchtst_finetune.py --dset etth1 --target_points 336 --n_heads 4 --d_model 16 --d_ff 128 --pretrained_model ./saved_models/etth1/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_gnoise0.1_model4.pth --is_finetune 1 --finetuned_model_id 4 --seed 2022
# !python patchtst_finetune.py --dset etth1 --target_points 336 --n_heads 4 --d_model 16 --d_ff 128 --pretrained_model ./saved_models/etth1/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_gnoise0.1_model5.pth --is_finetune 1 --finetuned_model_id 5 --seed 2023
# Out:
# args: Namespace(is_finetune=1, is_linear_probe=0, dset_finetune='etth1', context_points=512, target_points=336, batch_size=64, num_workers=0, scaler='standard', features='M', percent=100, patch_len=12, stride=12, revin=1, affine=0, n_layers=3, n_heads=4, d_model=16, d_ff=128, dropout=0.2, head_dropout=0.2, n_epochs_finetune=20, lr=0.0001, pretrained_model='./saved_models/etth1/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_gnoise0.1_model1.pth', finetuned_model_id=1, model_type='based_model', seed=2019)
# number of patches: 42
# number of model params 243184
# weights from ./saved_models/etth1/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_gnoise0.1_model1.pth successfully transferred!
#
# suggested_lr 0.00035938136638046257
# end-to-end finetuning
# number of patches: 42
# number of model params 243184
# ...

# %%
scores_mse = np.array([0.42375228, 0.42079568, 0.42570367, 0.4216434, 0.41926515])
scores_mae = np.array([0.43383744, 0.4288873, 0.43330428, 0.42915067, 0.42781585])

print(f'MSE: {np.mean(scores_mse):.3f} ± {np.std(scores_mse):.3f} | MAE: {np.mean(scores_mae):.3f} ± {np.std(scores_mae):.3f}')
# Out:
# MSE: 0.422 ± 0.002 | MAE: 0.431 ± 0.002

# %% [markdown]
# #### 3.2.4 Horizon 720

# %%
# !python patchtst_finetune.py --dset etth1 --target_points 720 --n_heads 4 --d_model 16 --d_ff 128 --pretrained_model ./saved_models/etth1/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_gnoise0.1_model1.pth --is_finetune 1 --finetuned_model_id 1 --seed 2019
# !python patchtst_finetune.py --dset etth1 --target_points 720 --n_heads 4 --d_model 16 --d_ff 128 --pretrained_model ./saved_models/etth1/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_gnoise0.1_model2.pth --is_finetune 1 --finetuned_model_id 2 --seed 2020
# !python patchtst_finetune.py --dset etth1 --target_points 720 --n_heads 4 --d_model 16 --d_ff 128 --pretrained_model ./saved_models/etth1/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_gnoise0.1_model3.pth --is_finetune 1 --finetuned_model_id 3 --seed 2021
# !python patchtst_finetune.py --dset etth1 --target_points 720 --n_heads 4 --d_model 16 --d_ff 128 --pretrained_model ./saved_models/etth1/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_gnoise0.1_model4.pth --is_finetune 1 --finetuned_model_id 4 --seed 2022
# !python patchtst_finetune.py --dset etth1 --target_points 720 --n_heads 4 --d_model 16 --d_ff 128 --pretrained_model ./saved_models/etth1/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_gnoise0.1_model5.pth --is_finetune 1 --finetuned_model_id 5 --seed 2023
# Out:
# args: Namespace(is_finetune=1, is_linear_probe=0, dset_finetune='etth1', context_points=512, target_points=720, batch_size=64, num_workers=0, scaler='standard', features='M', percent=100, patch_len=12, stride=12, revin=1, affine=0, n_layers=3, n_heads=4, d_model=16, d_ff=128, dropout=0.2, head_dropout=0.2, n_epochs_finetune=20, lr=0.0001, pretrained_model='./saved_models/etth1/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_gnoise0.1_model1.pth', finetuned_model_id=1, model_type='based_model', seed=2019)
# number of patches: 42
# number of model params 501616
# weights from ./saved_models/etth1/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_gnoise0.1_model1.pth successfully transferred!
#
# suggested_lr 0.001917910261672489
# end-to-end finetuning
# number of patches: 42
# number of model params 501616
# ...

# %%
scores_mse = np.array([0.43930912, 0.44447777, 0.4398457, 0.4403042, 0.43697757])
scores_mae = np.array([0.46000758, 0.4621657, 0.45975855, 0.4587362, 0.45851576])

print(f'MSE: {np.mean(scores_mse):.3f} ± {np.std(scores_mse):.3f} | MAE: {np.mean(scores_mae):.3f} ± {np.std(scores_mae):.3f}')
# Out:
# MSE: 0.440 ± 0.002 | MAE: 0.460 ± 0.001

# %% [markdown]
# **Note:** Zero masking's forecasting performance degrades with 100 pretraining epochs compared to 10 epochs across all horizons (except MAE for horizon 720), while Gaussian noise masking shows slight improvements. This suggests Gaussian noise is more robust to overfitting, likely due to 1. better gradient quality and 2. richer learning signals during pretraining.

# %% [markdown]
# ## 4. Few-Shot Learning (10% training data)
#
# In this section, we're going to evaluate our model's few-shot learning capability by using only 10% of the training data for both pretraining and fine-tuning.
#
# **Note:** We include supervised PatchTST as an additional baseline to access whether pretraining provides advantages over training from scratch in data-limited scenarios.

# %% [markdown]
# ### 4.1 Supervised Learning (Baseline)

# %%
# Traverse into the target directory
# %cd /content/PatchTST/PatchTST_supervised
# Out:
# /content/PatchTST/PatchTST_supervised

# %% [markdown]
# #### Horizon 96

# %%
# !python run_longExp.py --percent 10 --n_heads 4 --d_model 16 --d_ff 128 --model_id ETTh1_512_96_1 --model PatchTST --data ETTh1 --root_path /data/datasets/public/ETDataset/ETT-small/ --seq_len 512 --pred_len 96 --dropout 0.2 --fc_dropout 0.2 --head_dropout 0.2 --patch_len 12 --stride 12 --e_layers 3 --itr 1 --batch_size 64 --is_training 1 --random_seed 2019
# !python run_longExp.py --percent 10 --n_heads 4 --d_model 16 --d_ff 128 --model_id ETTh1_512_96_2 --model PatchTST --data ETTh1 --root_path /data/datasets/public/ETDataset/ETT-small/ --seq_len 512 --pred_len 96 --dropout 0.2 --fc_dropout 0.2 --head_dropout 0.2 --patch_len 12 --stride 12 --e_layers 3 --itr 1 --batch_size 64 --is_training 1 --random_seed 2020
# !python run_longExp.py --percent 10 --n_heads 4 --d_model 16 --d_ff 128 --model_id ETTh1_512_96_3 --model PatchTST --data ETTh1 --root_path /data/datasets/public/ETDataset/ETT-small/ --seq_len 512 --pred_len 96 --dropout 0.2 --fc_dropout 0.2 --head_dropout 0.2 --patch_len 12 --stride 12 --e_layers 3 --itr 1 --batch_size 64 --is_training 1 --random_seed 2021
# !python run_longExp.py --percent 10 --n_heads 4 --d_model 16 --d_ff 128 --model_id ETTh1_512_96_4 --model PatchTST --data ETTh1 --root_path /data/datasets/public/ETDataset/ETT-small/ --seq_len 512 --pred_len 96 --dropout 0.2 --fc_dropout 0.2 --head_dropout 0.2 --patch_len 12 --stride 12 --e_layers 3 --itr 1 --batch_size 64 --is_training 1 --random_seed 2022
# !python run_longExp.py --percent 10 --n_heads 4 --d_model 16 --d_ff 128 --model_id ETTh1_512_96_5 --model PatchTST --data ETTh1 --root_path /data/datasets/public/ETDataset/ETT-small/ --seq_len 512 --pred_len 96 --dropout 0.2 --fc_dropout 0.2 --head_dropout 0.2 --patch_len 12 --stride 12 --e_layers 3 --itr 1 --batch_size 64 --is_training 1 --random_seed 2023
# Out:
# Args in experiment:
# Namespace(random_seed=2019, is_training=1, model_id='ETTh1_512_96', model='PatchTST', data='ETTh1', root_path='/data/datasets/public/ETDataset/ETT-small/', data_path='ETTh1.csv', features='M', target='OT', freq='h', percent=10, checkpoints='./checkpoints/', seq_len=512, label_len=48, pred_len=96, fc_dropout=0.2, head_dropout=0.2, patch_len=12, stride=12, padding_patch='end', revin=1, affine=0, subtract_last=0, decomposition=0, kernel_size=25, individual=0, embed_type=0, enc_in=7, dec_in=7, c_out=7, d_model=16, n_heads=4, e_layers=3, d_layers=1, d_ff=128, moving_avg=25, factor=1, distil=True, dropout=0.2, embed='timeF', activation='gelu', output_attention=False, do_predict=False, num_workers=10, itr=1, train_epochs=100, batch_size=64, patience=100, learning_rate=0.0001, des='test', loss='mse', lradj='type3', pct_start=0.3, use_amp=False, use_gpu=True, gpu=0, use_multi_gpu=False, devices='0,1,2,3', test_flop=False)
# Use GPU: cuda:0
# ...

# %%
scores_mse = np.array([0.5119157433509827, 0.506636381149292, 0.5118086934089661, 0.5046238303184509, 0.49973422288894653])
scores_mae = np.array([0.4787907898426056, 0.4761987328529358, 0.4806058704853058, 0.47563493251800537, 0.4762074947357178])

print(f'MSE: {np.mean(scores_mse):.3f} ± {np.std(scores_mse):.3f} | MAE: {np.mean(scores_mae):.3f} ± {np.std(scores_mae):.3f}')
# Out:
# MSE: 0.507 ± 0.005 | MAE: 0.477 ± 0.002

# %% [markdown]
# #### Horizon 192

# %%
# !python run_longExp.py --percent 10 --n_heads 4 --d_model 16 --d_ff 128 --model_id ETTh1_512_192_1 --model PatchTST --data ETTh1 --root_path /data/datasets/public/ETDataset/ETT-small/ --seq_len 512 --pred_len 192 --dropout 0.2 --fc_dropout 0.2 --head_dropout 0.2 --patch_len 12 --stride 12 --e_layers 3 --itr 1 --batch_size 64 --is_training 1 --random_seed 2019
# !python run_longExp.py --percent 10 --n_heads 4 --d_model 16 --d_ff 128 --model_id ETTh1_512_192_2 --model PatchTST --data ETTh1 --root_path /data/datasets/public/ETDataset/ETT-small/ --seq_len 512 --pred_len 192 --dropout 0.2 --fc_dropout 0.2 --head_dropout 0.2 --patch_len 12 --stride 12 --e_layers 3 --itr 1 --batch_size 64 --is_training 1 --random_seed 2020
# !python run_longExp.py --percent 10 --n_heads 4 --d_model 16 --d_ff 128 --model_id ETTh1_512_192_3 --model PatchTST --data ETTh1 --root_path /data/datasets/public/ETDataset/ETT-small/ --seq_len 512 --pred_len 192 --dropout 0.2 --fc_dropout 0.2 --head_dropout 0.2 --patch_len 12 --stride 12 --e_layers 3 --itr 1 --batch_size 64 --is_training 1 --random_seed 2021
# !python run_longExp.py --percent 10 --n_heads 4 --d_model 16 --d_ff 128 --model_id ETTh1_512_192_4 --model PatchTST --data ETTh1 --root_path /data/datasets/public/ETDataset/ETT-small/ --seq_len 512 --pred_len 192 --dropout 0.2 --fc_dropout 0.2 --head_dropout 0.2 --patch_len 12 --stride 12 --e_layers 3 --itr 1 --batch_size 64 --is_training 1 --random_seed 2022
# !python run_longExp.py --percent 10 --n_heads 4 --d_model 16 --d_ff 128 --model_id ETTh1_512_192_5 --model PatchTST --data ETTh1 --root_path /data/datasets/public/ETDataset/ETT-small/ --seq_len 512 --pred_len 192 --dropout 0.2 --fc_dropout 0.2 --head_dropout 0.2 --patch_len 12 --stride 12 --e_layers 3 --itr 1 --batch_size 64 --is_training 1 --random_seed 2023
# Out:
# Args in experiment:
# Namespace(random_seed=2019, is_training=1, model_id='ETTh1_512_96', model='PatchTST', data='ETTh1', root_path='/data/datasets/public/ETDataset/ETT-small/', data_path='ETTh1.csv', features='M', target='OT', freq='h', percent=10, checkpoints='./checkpoints/', seq_len=512, label_len=48, pred_len=192, fc_dropout=0.2, head_dropout=0.2, patch_len=12, stride=12, padding_patch='end', revin=1, affine=0, subtract_last=0, decomposition=0, kernel_size=25, individual=0, embed_type=0, enc_in=7, dec_in=7, c_out=7, d_model=16, n_heads=4, e_layers=3, d_layers=1, d_ff=128, moving_avg=25, factor=1, distil=True, dropout=0.2, embed='timeF', activation='gelu', output_attention=False, do_predict=False, num_workers=10, itr=1, train_epochs=100, batch_size=64, patience=100, learning_rate=0.0001, des='test', loss='mse', lradj='type3', pct_start=0.3, use_amp=False, use_gpu=True, gpu=0, use_multi_gpu=False, devices='0,1,2,3', test_flop=False)
# Use GPU: cuda:0
# ...

# %%
scores_mse = np.array([0.5508699417114258, 0.5452966094017029, 0.5571723580360413, 0.549470841884613, 0.5416373610496521])
scores_mae = np.array([0.5006357431411743, 0.4978310763835907, 0.5052049160003662, 0.49983254075050354, 0.4994324743747711])

print(f'MSE: {np.mean(scores_mse):.3f} ± {np.std(scores_mse):.3f} | MAE: {np.mean(scores_mae):.3f} ± {np.std(scores_mae):.3f}')
# Out:
# MSE: 0.549 ± 0.005 | MAE: 0.501 ± 0.002

# %% [markdown]
# #### Horizon 336

# %%
# !python run_longExp.py --percent 10 --n_heads 4 --d_model 16 --d_ff 128 --model_id ETTh1_512_336_1 --model PatchTST --data ETTh1 --root_path /data/datasets/public/ETDataset/ETT-small/ --seq_len 512 --pred_len 336 --dropout 0.2 --fc_dropout 0.2 --head_dropout 0.2 --patch_len 12 --stride 12 --e_layers 3 --itr 1 --batch_size 64 --is_training 1 --random_seed 2019
# !python run_longExp.py --percent 10 --n_heads 4 --d_model 16 --d_ff 128 --model_id ETTh1_512_336_2 --model PatchTST --data ETTh1 --root_path /data/datasets/public/ETDataset/ETT-small/ --seq_len 512 --pred_len 336 --dropout 0.2 --fc_dropout 0.2 --head_dropout 0.2 --patch_len 12 --stride 12 --e_layers 3 --itr 1 --batch_size 64 --is_training 1 --random_seed 2020
# !python run_longExp.py --percent 10 --n_heads 4 --d_model 16 --d_ff 128 --model_id ETTh1_512_336_3 --model PatchTST --data ETTh1 --root_path /data/datasets/public/ETDataset/ETT-small/ --seq_len 512 --pred_len 336 --dropout 0.2 --fc_dropout 0.2 --head_dropout 0.2 --patch_len 12 --stride 12 --e_layers 3 --itr 1 --batch_size 64 --is_training 1 --random_seed 2021
# !python run_longExp.py --percent 10 --n_heads 4 --d_model 16 --d_ff 128 --model_id ETTh1_512_336_4 --model PatchTST --data ETTh1 --root_path /data/datasets/public/ETDataset/ETT-small/ --seq_len 512 --pred_len 336 --dropout 0.2 --fc_dropout 0.2 --head_dropout 0.2 --patch_len 12 --stride 12 --e_layers 3 --itr 1 --batch_size 64 --is_training 1 --random_seed 2022
# !python run_longExp.py --percent 10 --n_heads 4 --d_model 16 --d_ff 128 --model_id ETTh1_512_336_5 --model PatchTST --data ETTh1 --root_path /data/datasets/public/ETDataset/ETT-small/ --seq_len 512 --pred_len 336 --dropout 0.2 --fc_dropout 0.2 --head_dropout 0.2 --patch_len 12 --stride 12 --e_layers 3 --itr 1 --batch_size 64 --is_training 1 --random_seed 2023
# Out:
# Args in experiment:
# Namespace(random_seed=2019, is_training=1, model_id='ETTh1_512_336_1', model='PatchTST', data='ETTh1', root_path='/data/datasets/public/ETDataset/ETT-small/', data_path='ETTh1.csv', features='M', target='OT', freq='h', percent=10, checkpoints='./checkpoints/', seq_len=512, label_len=48, pred_len=336, fc_dropout=0.2, head_dropout=0.2, patch_len=12, stride=12, padding_patch='end', revin=1, affine=0, subtract_last=0, decomposition=0, kernel_size=25, individual=0, embed_type=0, enc_in=7, dec_in=7, c_out=7, d_model=16, n_heads=4, e_layers=3, d_layers=1, d_ff=128, moving_avg=25, factor=1, distil=True, dropout=0.2, embed='timeF', activation='gelu', output_attention=False, do_predict=False, num_workers=10, itr=1, train_epochs=100, batch_size=64, patience=100, learning_rate=0.0001, des='test', loss='mse', lradj='type3', pct_start=0.3, use_amp=False, use_gpu=True, gpu=0, use_multi_gpu=False, devices='0,1,2,3', test_flop=False)
# Use GPU: cuda:0
# ...

# %%
scores_mse = np.array([0.5627166032791138, 0.567887544631958, 0.5802090764045715, 0.5647238492965698, 0.5585991740226746])
scores_mae = np.array([0.5170679688453674, 0.5187626481056213, 0.5268067717552185, 0.5175920128822327, 0.5169575214385986])

print(f'MSE: {np.mean(scores_mse):.3f} ± {np.std(scores_mse):.3f} | MAE: {np.mean(scores_mae):.3f} ± {np.std(scores_mae):.3f}')
# Out:
# MSE: 0.567 ± 0.007 | MAE: 0.519 ± 0.004

# %% [markdown]
# #### Horizon 720

# %%
# !python run_longExp.py --percent 10 --n_heads 4 --d_model 16 --d_ff 128 --model_id ETTh1_512_720_1 --model PatchTST --data ETTh1 --root_path /data/datasets/public/ETDataset/ETT-small/ --seq_len 512 --pred_len 720 --dropout 0.2 --fc_dropout 0.2 --head_dropout 0.2 --patch_len 12 --stride 12 --e_layers 3 --itr 1 --batch_size 64 --is_training 1 --random_seed 2019
# !python run_longExp.py --percent 10 --n_heads 4 --d_model 16 --d_ff 128 --model_id ETTh1_512_720_2 --model PatchTST --data ETTh1 --root_path /data/datasets/public/ETDataset/ETT-small/ --seq_len 512 --pred_len 720 --dropout 0.2 --fc_dropout 0.2 --head_dropout 0.2 --patch_len 12 --stride 12 --e_layers 3 --itr 1 --batch_size 64 --is_training 1 --random_seed 2020
# !python run_longExp.py --percent 10 --n_heads 4 --d_model 16 --d_ff 128 --model_id ETTh1_512_720_3 --model PatchTST --data ETTh1 --root_path /data/datasets/public/ETDataset/ETT-small/ --seq_len 512 --pred_len 720 --dropout 0.2 --fc_dropout 0.2 --head_dropout 0.2 --patch_len 12 --stride 12 --e_layers 3 --itr 1 --batch_size 64 --is_training 1 --random_seed 2021
# !python run_longExp.py --percent 10 --n_heads 4 --d_model 16 --d_ff 128 --model_id ETTh1_512_720_4 --model PatchTST --data ETTh1 --root_path /data/datasets/public/ETDataset/ETT-small/ --seq_len 512 --pred_len 720 --dropout 0.2 --fc_dropout 0.2 --head_dropout 0.2 --patch_len 12 --stride 12 --e_layers 3 --itr 1 --batch_size 64 --is_training 1 --random_seed 2022
# !python run_longExp.py --percent 10 --n_heads 4 --d_model 16 --d_ff 128 --model_id ETTh1_512_720_5 --model PatchTST --data ETTh1 --root_path /data/datasets/public/ETDataset/ETT-small/ --seq_len 512 --pred_len 720 --dropout 0.2 --fc_dropout 0.2 --head_dropout 0.2 --patch_len 12 --stride 12 --e_layers 3 --itr 1 --batch_size 64 --is_training 1 --random_seed 2023
# Out:
# Args in experiment:
# Namespace(random_seed=2019, is_training=1, model_id='ETTh1_512_720_1', model='PatchTST', data='ETTh1', root_path='/data/datasets/public/ETDataset/ETT-small/', data_path='ETTh1.csv', features='M', target='OT', freq='h', percent=10, checkpoints='./checkpoints/', seq_len=512, label_len=48, pred_len=720, fc_dropout=0.2, head_dropout=0.2, patch_len=12, stride=12, padding_patch='end', revin=1, affine=0, subtract_last=0, decomposition=0, kernel_size=25, individual=0, embed_type=0, enc_in=7, dec_in=7, c_out=7, d_model=16, n_heads=4, e_layers=3, d_layers=1, d_ff=128, moving_avg=25, factor=1, distil=True, dropout=0.2, embed='timeF', activation='gelu', output_attention=False, do_predict=False, num_workers=10, itr=1, train_epochs=100, batch_size=64, patience=100, learning_rate=0.0001, des='test', loss='mse', lradj='type3', pct_start=0.3, use_amp=False, use_gpu=True, gpu=0, use_multi_gpu=False, devices='0,1,2,3', test_flop=False)
# Use GPU: cuda:0
# ...

# %%
scores_mse = np.array([0.7999082803726196, 0.7709165215492249, 0.807617723941803, 0.8095522522926331, 0.7926304340362549])
scores_mae = np.array([0.6336519718170166, 0.6235697865486145, 0.6361264586448669, 0.6367616653442383, 0.6311259865760803])

print(f'MSE: {np.mean(scores_mse):.3f} ± {np.std(scores_mse):.3f} | MAE: {np.mean(scores_mae):.3f} ± {np.std(scores_mae):.3f}')
# Out:
# MSE: 0.796 ± 0.014 | MAE: 0.632 ± 0.005

# %% [markdown]
# ### 4.2 Zero Masking (Baseline)

# %% [markdown]
# #### 4.2.1 Pre-training

# %%
# !python patchtst_pretrain.py --dset etth1 --percent 10 --n_heads 4 --d_model 16 --d_ff 128 --n_epochs_pretrain 100 --pretrained_model_id 1 --seed 2019
# !python patchtst_pretrain.py --dset etth1 --percent 10 --n_heads 4 --d_model 16 --d_ff 128 --n_epochs_pretrain 100 --pretrained_model_id 2 --seed 2020
# !python patchtst_pretrain.py --dset etth1 --percent 10 --n_heads 4 --d_model 16 --d_ff 128 --n_epochs_pretrain 100 --pretrained_model_id 3 --seed 2021
# !python patchtst_pretrain.py --dset etth1 --percent 10 --n_heads 4 --d_model 16 --d_ff 128 --n_epochs_pretrain 100 --pretrained_model_id 4 --seed 2022
# !python patchtst_pretrain.py --dset etth1 --percent 10 --n_heads 4 --d_model 16 --d_ff 128 --n_epochs_pretrain 100 --pretrained_model_id 5 --seed 2023
# Out:
# args: Namespace(dset_pretrain='etth1', context_points=512, target_points=96, batch_size=64, num_workers=0, scaler='standard', features='M', percent=10, patch_len=12, stride=12, revin=1, n_layers=3, n_heads=4, d_model=16, d_ff=128, dropout=0.2, head_dropout=0.2, mask_ratio=0.4, use_gaussian_noise=0, noise_std=0.1, n_epochs_pretrain=100, lr=0.0001, pretrained_model_id=1, model_type='based_model', seed=2019)
# number of patches: 42
# number of model params 17260
# suggested_lr 0.001917910261672489
# number of patches: 42
# number of model params 17260
#           epoch     train_loss     valid_loss           time
# Better model found at epoch 0 with valid_loss value: 1.0119962901144524.
#               0       1.079631       1.011996          00:00
# Better model found at epoch 1 with valid_loss value: 1.004031695326526.
#               1       1.074478       1.004032          00:00
# Better model found at epoch 2 with valid_loss value: 0.9976053179701526.
# ...

# %% [markdown]
# #### 4.2.2 Fine-tuning

# %% [markdown]
# ##### Horizon 96

# %%
# !python patchtst_finetune.py --dset etth1 --percent 10 --n_heads 4 --d_model 16 --d_ff 128 --pretrained_model ./saved_models/etth1/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_zero_pct10_model1.pth --is_finetune 1 --finetuned_model_id 1 --seed 2019
# !python patchtst_finetune.py --dset etth1 --percent 10 --n_heads 4 --d_model 16 --d_ff 128 --pretrained_model ./saved_models/etth1/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_zero_pct10_model2.pth --is_finetune 1 --finetuned_model_id 2 --seed 2020
# !python patchtst_finetune.py --dset etth1 --percent 10 --n_heads 4 --d_model 16 --d_ff 128 --pretrained_model ./saved_models/etth1/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_zero_pct10_model3.pth --is_finetune 1 --finetuned_model_id 3 --seed 2021
# !python patchtst_finetune.py --dset etth1 --percent 10 --n_heads 4 --d_model 16 --d_ff 128 --pretrained_model ./saved_models/etth1/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_zero_pct10_model4.pth --is_finetune 1 --finetuned_model_id 4 --seed 2022
# !python patchtst_finetune.py --dset etth1 --percent 10 --n_heads 4 --d_model 16 --d_ff 128 --pretrained_model ./saved_models/etth1/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_zero_pct10_model5.pth --is_finetune 1 --finetuned_model_id 5 --seed 2023
# Out:
# args: Namespace(is_finetune=1, is_linear_probe=0, dset_finetune='etth1', context_points=512, target_points=96, batch_size=64, num_workers=0, scaler='standard', features='M', percent=10, patch_len=12, stride=12, revin=1, affine=0, n_layers=3, n_heads=4, d_model=16, d_ff=128, dropout=0.2, head_dropout=0.2, n_epochs_finetune=20, lr=0.0001, pretrained_model='./saved_models/etth1/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_zero_pct10_model1.pth', finetuned_model_id=1, model_type='based_model', seed=2019)
# number of patches: 42
# number of model params 81664
# weights from ./saved_models/etth1/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_zero_pct10_model1.pth successfully transferred!
#
# suggested_lr 0.0010974987654930567
# end-to-end finetuning
# number of patches: 42
# number of model params 81664
# ...

# %%
# Evaluate the results
scores_mse = np.array([0.49287045, 0.4898086, 0.5205203, 0.48136136, 0.50902206])
scores_mae = np.array([0.47054172, 0.4701855, 0.48912692, 0.4669255, 0.47854334])

print(f'MSE: {np.mean(scores_mse):.3f} ± {np.std(scores_mse):.3f} | MAE: {np.mean(scores_mae):.3f} ± {np.std(scores_mae):.3f}')
# Out:
# MSE: 0.499 ± 0.014 | MAE: 0.475 ± 0.008

# %% [markdown]
# ##### Horizon 192

# %%
# !python patchtst_finetune.py --dset etth1 --percent 10 --target_points 192 --n_heads 4 --d_model 16 --d_ff 128 --pretrained_model ./saved_models/etth1/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_zero_pct10_model1.pth --is_finetune 1 --finetuned_model_id 1 --seed 2019
# !python patchtst_finetune.py --dset etth1 --percent 10 --target_points 192 --n_heads 4 --d_model 16 --d_ff 128 --pretrained_model ./saved_models/etth1/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_zero_pct10_model2.pth --is_finetune 1 --finetuned_model_id 2 --seed 2020
# !python patchtst_finetune.py --dset etth1 --percent 10 --target_points 192 --n_heads 4 --d_model 16 --d_ff 128 --pretrained_model ./saved_models/etth1/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_zero_pct10_model3.pth --is_finetune 1 --finetuned_model_id 3 --seed 2021
# !python patchtst_finetune.py --dset etth1 --percent 10 --target_points 192 --n_heads 4 --d_model 16 --d_ff 128 --pretrained_model ./saved_models/etth1/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_zero_pct10_model4.pth --is_finetune 1 --finetuned_model_id 4 --seed 2022
# !python patchtst_finetune.py --dset etth1 --percent 10 --target_points 192 --n_heads 4 --d_model 16 --d_ff 128 --pretrained_model ./saved_models/etth1/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_zero_pct10_model5.pth --is_finetune 1 --finetuned_model_id 5 --seed 2023
# Out:
# args: Namespace(is_finetune=1, is_linear_probe=0, dset_finetune='etth1', context_points=512, target_points=192, batch_size=64, num_workers=0, scaler='standard', features='M', percent=10, patch_len=12, stride=12, revin=1, affine=0, n_layers=3, n_heads=4, d_model=16, d_ff=128, dropout=0.2, head_dropout=0.2, n_epochs_finetune=20, lr=0.0001, pretrained_model='./saved_models/etth1/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_zero_pct10_model1.pth', finetuned_model_id=1, model_type='based_model', seed=2019)
# number of patches: 42
# number of model params 146272
# weights from ./saved_models/etth1/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_zero_pct10_model1.pth successfully transferred!
#
# suggested_lr 0.0010974987654930567
# end-to-end finetuning
# number of patches: 42
# number of model params 146272
# ...

# %%
# Evaluate the results
scores_mse = np.array([0.54919213, 0.6113375, 0.56810194, 0.54037553, 0.5660829])
scores_mae = np.array([0.49921766, 0.5209248, 0.5047014, 0.4939779, 0.5034618])

print(f'MSE: {np.mean(scores_mse):.3f} ± {np.std(scores_mse):.3f} | MAE: {np.mean(scores_mae):.3f} ± {np.std(scores_mae):.3f}')
# Out:
# MSE: 0.567 ± 0.024 | MAE: 0.504 ± 0.009

# %% [markdown]
# ##### Horizon 336

# %%
# !python patchtst_finetune.py --dset etth1 --percent 10 --target_points 336 --n_heads 4 --d_model 16 --d_ff 128 --pretrained_model ./saved_models/etth1/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_zero_pct10_model1.pth --is_finetune 1 --finetuned_model_id 1 --seed 2019
# !python patchtst_finetune.py --dset etth1 --percent 10 --target_points 336 --n_heads 4 --d_model 16 --d_ff 128 --pretrained_model ./saved_models/etth1/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_zero_pct10_model2.pth --is_finetune 1 --finetuned_model_id 2 --seed 2020
# !python patchtst_finetune.py --dset etth1 --percent 10 --target_points 336 --n_heads 4 --d_model 16 --d_ff 128 --pretrained_model ./saved_models/etth1/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_zero_pct10_model3.pth --is_finetune 1 --finetuned_model_id 3 --seed 2021
# !python patchtst_finetune.py --dset etth1 --percent 10 --target_points 336 --n_heads 4 --d_model 16 --d_ff 128 --pretrained_model ./saved_models/etth1/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_zero_pct10_model4.pth --is_finetune 1 --finetuned_model_id 4 --seed 2022
# !python patchtst_finetune.py --dset etth1 --percent 10 --target_points 336 --n_heads 4 --d_model 16 --d_ff 128 --pretrained_model ./saved_models/etth1/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_zero_pct10_model5.pth --is_finetune 1 --finetuned_model_id 5 --seed 2023
# Out:
# args: Namespace(is_finetune=1, is_linear_probe=0, dset_finetune='etth1', context_points=512, target_points=336, batch_size=64, num_workers=0, scaler='standard', features='M', percent=10, patch_len=12, stride=12, revin=1, affine=0, n_layers=3, n_heads=4, d_model=16, d_ff=128, dropout=0.2, head_dropout=0.2, n_epochs_finetune=20, lr=0.0001, pretrained_model='./saved_models/etth1/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_zero_pct10_model1.pth', finetuned_model_id=1, model_type='based_model', seed=2019)
# number of patches: 42
# number of model params 243184
# weights from ./saved_models/etth1/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_zero_pct10_model1.pth successfully transferred!
#
# suggested_lr 0.000756463327554629
# end-to-end finetuning
# number of patches: 42
# number of model params 243184
# ...

# %%
# Evaluate the results
scores_mse = np.array([0.6193777, 0.6688852, 0.65907353, 0.61323893, 0.615147])
scores_mae = np.array([0.52892876, 0.5476163, 0.5440223, 0.5402164, 0.5299363])

print(f'MSE: {np.mean(scores_mse):.3f} ± {np.std(scores_mse):.3f} | MAE: {np.mean(scores_mae):.3f} ± {np.std(scores_mae):.3f}')
# Out:
# MSE: 0.635 ± 0.024 | MAE: 0.538 ± 0.007

# %% [markdown]
# ##### Horizon 720

# %%
# !python patchtst_finetune.py --dset etth1 --percent 10 --target_points 720 --n_heads 4 --d_model 16 --d_ff 128 --pretrained_model ./saved_models/etth1/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_zero_pct10_model1.pth --is_finetune 1 --finetuned_model_id 1 --seed 2019
# !python patchtst_finetune.py --dset etth1 --percent 10 --target_points 720 --n_heads 4 --d_model 16 --d_ff 128 --pretrained_model ./saved_models/etth1/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_zero_pct10_model2.pth --is_finetune 1 --finetuned_model_id 2 --seed 2020
# !python patchtst_finetune.py --dset etth1 --percent 10 --target_points 720 --n_heads 4 --d_model 16 --d_ff 128 --pretrained_model ./saved_models/etth1/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_zero_pct10_model3.pth --is_finetune 1 --finetuned_model_id 3 --seed 2021
# !python patchtst_finetune.py --dset etth1 --percent 10 --target_points 720 --n_heads 4 --d_model 16 --d_ff 128 --pretrained_model ./saved_models/etth1/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_zero_pct10_model4.pth --is_finetune 1 --finetuned_model_id 4 --seed 2022
# !python patchtst_finetune.py --dset etth1 --percent 10 --target_points 720 --n_heads 4 --d_model 16 --d_ff 128 --pretrained_model ./saved_models/etth1/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_zero_pct10_model5.pth --is_finetune 1 --finetuned_model_id 5 --seed 2023
# Out:
# args: Namespace(is_finetune=1, is_linear_probe=0, dset_finetune='etth1', context_points=512, target_points=720, batch_size=64, num_workers=0, scaler='standard', features='M', percent=10, patch_len=12, stride=12, revin=1, affine=0, n_layers=3, n_heads=4, d_model=16, d_ff=128, dropout=0.2, head_dropout=0.2, n_epochs_finetune=20, lr=0.0001, pretrained_model='./saved_models/etth1/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_zero_pct10_model1.pth', finetuned_model_id=1, model_type='based_model', seed=2019)
# number of patches: 42
# number of model params 501616
# weights from ./saved_models/etth1/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_zero_pct10_model1.pth successfully transferred!
#
# suggested_lr 0.0005214008287999684
# end-to-end finetuning
# number of patches: 42
# number of model params 501616
# ...

# %%
# Evaluate the results
scores_mse = np.array([0.7930883, 0.7921591, 0.7952341, 0.8101272, 0.8006463])
scores_mae = np.array([0.62680244, 0.62722385, 0.62813675, 0.63232476, 0.63015705])

print(f'MSE: {np.mean(scores_mse):.3f} ± {np.std(scores_mse):.3f} | MAE: {np.mean(scores_mae):.3f} ± {np.std(scores_mae):.3f}')
# Out:
# MSE: 0.798 ± 0.007 | MAE: 0.629 ± 0.002

# %% [markdown]
# ### 4.3 Gaussian Noise Addition

# %% [markdown]
# #### 4.3.1 Pre-training

# %%
# !python patchtst_pretrain.py --dset etth1 --percent 10 --n_heads 4 --d_model 16 --d_ff 128 --use_gaussian_noise 1 --noise_std 0.1 --n_epochs_pretrain 100 --pretrained_model_id 1 --seed 2019
# !python patchtst_pretrain.py --dset etth1 --percent 10 --n_heads 4 --d_model 16 --d_ff 128 --use_gaussian_noise 1 --noise_std 0.1 --n_epochs_pretrain 100 --pretrained_model_id 2 --seed 2020
# !python patchtst_pretrain.py --dset etth1 --percent 10 --n_heads 4 --d_model 16 --d_ff 128 --use_gaussian_noise 1 --noise_std 0.1 --n_epochs_pretrain 100 --pretrained_model_id 3 --seed 2021
# !python patchtst_pretrain.py --dset etth1 --percent 10 --n_heads 4 --d_model 16 --d_ff 128 --use_gaussian_noise 1 --noise_std 0.1 --n_epochs_pretrain 100 --pretrained_model_id 4 --seed 2022
# !python patchtst_pretrain.py --dset etth1 --percent 10 --n_heads 4 --d_model 16 --d_ff 128 --use_gaussian_noise 1 --noise_std 0.1 --n_epochs_pretrain 100 --pretrained_model_id 5 --seed 2023
# Out:
# args: Namespace(dset_pretrain='etth1', context_points=512, target_points=96, batch_size=64, num_workers=0, scaler='standard', features='M', percent=10, patch_len=12, stride=12, revin=1, n_layers=3, n_heads=4, d_model=16, d_ff=128, dropout=0.2, head_dropout=0.2, mask_ratio=0.4, use_gaussian_noise=1, noise_std=0.1, n_epochs_pretrain=100, lr=0.0001, pretrained_model_id=1, model_type='based_model', seed=2019)
# number of patches: 42
# number of model params 17260
# suggested_lr 0.0006280291441834253
# number of patches: 42
# number of model params 17260
#           epoch     train_loss     valid_loss           time
# Better model found at epoch 0 with valid_loss value: 1.1066575439014812.
#               0       1.350371       1.106658          00:00
#               1       1.327588       1.111007          00:00
# Better model found at epoch 2 with valid_loss value: 1.095079141887343.
#               2       1.302696       1.095079          00:00
# ...

# %% [markdown]
# #### 4.3.2 Fine-tuning

# %% [markdown]
# ##### Horizon 96

# %%
# !python patchtst_finetune.py --dset etth1 --percent 10 --n_heads 4 --d_model 16 --d_ff 128 --pretrained_model ./saved_models/etth1/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_gnoise0.1_pct10_model1.pth --is_finetune 1 --finetuned_model_id 1 --seed 2019
# !python patchtst_finetune.py --dset etth1 --percent 10 --n_heads 4 --d_model 16 --d_ff 128 --pretrained_model ./saved_models/etth1/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_gnoise0.1_pct10_model2.pth --is_finetune 1 --finetuned_model_id 2 --seed 2020
# !python patchtst_finetune.py --dset etth1 --percent 10 --n_heads 4 --d_model 16 --d_ff 128 --pretrained_model ./saved_models/etth1/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_gnoise0.1_pct10_model3.pth --is_finetune 1 --finetuned_model_id 3 --seed 2021
# !python patchtst_finetune.py --dset etth1 --percent 10 --n_heads 4 --d_model 16 --d_ff 128 --pretrained_model ./saved_models/etth1/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_gnoise0.1_pct10_model4.pth --is_finetune 1 --finetuned_model_id 4 --seed 2022
# !python patchtst_finetune.py --dset etth1 --percent 10 --n_heads 4 --d_model 16 --d_ff 128 --pretrained_model ./saved_models/etth1/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_gnoise0.1_pct10_model5.pth --is_finetune 1 --finetuned_model_id 5 --seed 2023
# Out:
# args: Namespace(is_finetune=1, is_linear_probe=0, dset_finetune='etth1', context_points=512, target_points=96, batch_size=64, num_workers=0, scaler='standard', features='M', percent=10, patch_len=12, stride=12, revin=1, affine=0, n_layers=3, n_heads=4, d_model=16, d_ff=128, dropout=0.2, head_dropout=0.2, n_epochs_finetune=20, lr=0.0001, pretrained_model='./saved_models/etth1/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_gnoise0.1_pct10_model1.pth', finetuned_model_id=1, model_type='based_model', seed=2019)
# number of patches: 42
# number of model params 81664
# weights from ./saved_models/etth1/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_gnoise0.1_pct10_model1.pth successfully transferred!
#
# suggested_lr 0.0010974987654930567
# end-to-end finetuning
# number of patches: 42
# number of model params 81664
# ...

# %%
# Evaluate the results
scores_mse = np.array([0.4422296, 0.4467313, 0.44630885, 0.43978885, 0.4465525])
scores_mae = np.array([0.44660085, 0.4503494, 0.44875902, 0.44458205, 0.45113456])

print(f'MSE: {np.mean(scores_mse):.3f} ± {np.std(scores_mse):.3f} | MAE: {np.mean(scores_mae):.3f} ± {np.std(scores_mae):.3f}')
# Out:
# MSE: 0.444 ± 0.003 | MAE: 0.448 ± 0.002

# %% [markdown]
# ##### Horizon 192

# %%
# !python patchtst_finetune.py --dset etth1 --percent 10 --target_points 192 --n_heads 4 --d_model 16 --d_ff 128 --pretrained_model ./saved_models/etth1/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_gnoise0.1_pct10_model1.pth --is_finetune 1 --finetuned_model_id 1 --seed 2019
# !python patchtst_finetune.py --dset etth1 --percent 10 --target_points 192 --n_heads 4 --d_model 16 --d_ff 128 --pretrained_model ./saved_models/etth1/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_gnoise0.1_pct10_model2.pth --is_finetune 1 --finetuned_model_id 2 --seed 2020
# !python patchtst_finetune.py --dset etth1 --percent 10 --target_points 192 --n_heads 4 --d_model 16 --d_ff 128 --pretrained_model ./saved_models/etth1/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_gnoise0.1_pct10_model3.pth --is_finetune 1 --finetuned_model_id 3 --seed 2021
# !python patchtst_finetune.py --dset etth1 --percent 10 --target_points 192 --n_heads 4 --d_model 16 --d_ff 128 --pretrained_model ./saved_models/etth1/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_gnoise0.1_pct10_model4.pth --is_finetune 1 --finetuned_model_id 4 --seed 2022
# !python patchtst_finetune.py --dset etth1 --percent 10 --target_points 192 --n_heads 4 --d_model 16 --d_ff 128 --pretrained_model ./saved_models/etth1/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_gnoise0.1_pct10_model5.pth --is_finetune 1 --finetuned_model_id 5 --seed 2023
# Out:
# args: Namespace(is_finetune=1, is_linear_probe=0, dset_finetune='etth1', context_points=512, target_points=192, batch_size=64, num_workers=0, scaler='standard', features='M', percent=10, patch_len=12, stride=12, revin=1, affine=0, n_layers=3, n_heads=4, d_model=16, d_ff=128, dropout=0.2, head_dropout=0.2, n_epochs_finetune=20, lr=0.0001, pretrained_model='./saved_models/etth1/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_gnoise0.1_pct10_model1.pth', finetuned_model_id=1, model_type='based_model', seed=2019)
# number of patches: 42
# number of model params 146272
# weights from ./saved_models/etth1/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_gnoise0.1_pct10_model1.pth successfully transferred!
#
# suggested_lr 0.0009111627561154895
# end-to-end finetuning
# number of patches: 42
# number of model params 146272
# ...

# %%
# Evaluate the results
scores_mse = np.array([0.47863567, 0.4853824, 0.4876355, 0.47060052, 0.4907334])
scores_mae = np.array([0.47138563, 0.47574165, 0.47669786, 0.4660848, 0.47830087])

print(f'MSE: {np.mean(scores_mse):.3f} ± {np.std(scores_mse):.3f} | MAE: {np.mean(scores_mae):.3f} ± {np.std(scores_mae):.3f}')
# Out:
# MSE: 0.483 ± 0.007 | MAE: 0.474 ± 0.004

# %% [markdown]
# ##### Horizon 336

# %%
# !python patchtst_finetune.py --dset etth1 --percent 10 --target_points 336 --n_heads 4 --d_model 16 --d_ff 128 --pretrained_model ./saved_models/etth1/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_gnoise0.1_pct10_model1.pth --is_finetune 1 --finetuned_model_id 1 --seed 2019
# !python patchtst_finetune.py --dset etth1 --percent 10 --target_points 336 --n_heads 4 --d_model 16 --d_ff 128 --pretrained_model ./saved_models/etth1/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_gnoise0.1_pct10_model2.pth --is_finetune 1 --finetuned_model_id 2 --seed 2020
# !python patchtst_finetune.py --dset etth1 --percent 10 --target_points 336 --n_heads 4 --d_model 16 --d_ff 128 --pretrained_model ./saved_models/etth1/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_gnoise0.1_pct10_model3.pth --is_finetune 1 --finetuned_model_id 3 --seed 2021
# !python patchtst_finetune.py --dset etth1 --percent 10 --target_points 336 --n_heads 4 --d_model 16 --d_ff 128 --pretrained_model ./saved_models/etth1/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_gnoise0.1_pct10_model4.pth --is_finetune 1 --finetuned_model_id 4 --seed 2022
# !python patchtst_finetune.py --dset etth1 --percent 10 --target_points 336 --n_heads 4 --d_model 16 --d_ff 128 --pretrained_model ./saved_models/etth1/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_gnoise0.1_pct10_model5.pth --is_finetune 1 --finetuned_model_id 5 --seed 2023
# Out:
# args: Namespace(is_finetune=1, is_linear_probe=0, dset_finetune='etth1', context_points=512, target_points=336, batch_size=64, num_workers=0, scaler='standard', features='M', percent=10, patch_len=12, stride=12, revin=1, affine=0, n_layers=3, n_heads=4, d_model=16, d_ff=128, dropout=0.2, head_dropout=0.2, n_epochs_finetune=20, lr=0.0001, pretrained_model='./saved_models/etth1/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_gnoise0.1_pct10_model1.pth', finetuned_model_id=1, model_type='based_model', seed=2019)
# number of patches: 42
# number of model params 243184
# weights from ./saved_models/etth1/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_gnoise0.1_pct10_model1.pth successfully transferred!
#
# suggested_lr 0.00043287612810830566
# end-to-end finetuning
# number of patches: 42
# number of model params 243184
# ...

# %%
# Evaluate the results
scores_mse = np.array([0.5264433, 0.54518914, 0.5257991, 0.51615256, 0.5300791])
scores_mae = np.array([0.50563335, 0.5174833, 0.5065873, 0.50151783, 0.5079289])

print(f'MSE: {np.mean(scores_mse):.3f} ± {np.std(scores_mse):.3f} | MAE: {np.mean(scores_mae):.3f} ± {np.std(scores_mae):.3f}')
# Out:
# MSE: 0.529 ± 0.009 | MAE: 0.508 ± 0.005

# %% [markdown]
# ##### Horizon 720

# %%
# !python patchtst_finetune.py --dset etth1 --percent 10 --target_points 720 --n_heads 4 --d_model 16 --d_ff 128 --pretrained_model ./saved_models/etth1/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_gnoise0.1_pct10_model1.pth --is_finetune 1 --finetuned_model_id 1 --seed 2019
# !python patchtst_finetune.py --dset etth1 --percent 10 --target_points 720 --n_heads 4 --d_model 16 --d_ff 128 --pretrained_model ./saved_models/etth1/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_gnoise0.1_pct10_model2.pth --is_finetune 1 --finetuned_model_id 2 --seed 2020
# !python patchtst_finetune.py --dset etth1 --percent 10 --target_points 720 --n_heads 4 --d_model 16 --d_ff 128 --pretrained_model ./saved_models/etth1/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_gnoise0.1_pct10_model3.pth --is_finetune 1 --finetuned_model_id 3 --seed 2021
# !python patchtst_finetune.py --dset etth1 --percent 10 --target_points 720 --n_heads 4 --d_model 16 --d_ff 128 --pretrained_model ./saved_models/etth1/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_gnoise0.1_pct10_model4.pth --is_finetune 1 --finetuned_model_id 4 --seed 2022
# !python patchtst_finetune.py --dset etth1 --percent 10 --target_points 720 --n_heads 4 --d_model 16 --d_ff 128 --pretrained_model ./saved_models/etth1/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_gnoise0.1_pct10_model5.pth --is_finetune 1 --finetuned_model_id 5 --seed 2023
# Out:
# args: Namespace(is_finetune=1, is_linear_probe=0, dset_finetune='etth1', context_points=512, target_points=720, batch_size=64, num_workers=0, scaler='standard', features='M', percent=10, patch_len=12, stride=12, revin=1, affine=0, n_layers=3, n_heads=4, d_model=16, d_ff=128, dropout=0.2, head_dropout=0.2, n_epochs_finetune=20, lr=0.0001, pretrained_model='./saved_models/etth1/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_gnoise0.1_pct10_model1.pth', finetuned_model_id=1, model_type='based_model', seed=2019)
# number of patches: 42
# number of model params 501616
# weights from ./saved_models/etth1/masked_patchtst/based_model/patchtst_pretrained_cw512_patch12_stride12_epochs-pretrain100_mask0.4_gnoise0.1_pct10_model1.pth successfully transferred!
#
# suggested_lr 0.00035938136638046257
# end-to-end finetuning
# number of patches: 42
# number of model params 501616
# ...

# %%
# Evaluate the results
scores_mse = np.array([0.7621617, 0.7505404, 0.76030177, 0.7444848, 0.7611813])
scores_mae = np.array([0.6192484, 0.6140759, 0.6175063, 0.61116123, 0.61794084])

print(f'MSE: {np.mean(scores_mse):.3f} ± {np.std(scores_mse):.3f} | MAE: {np.mean(scores_mae):.3f} ± {np.std(scores_mae):.3f}')
# Out:
# MSE: 0.756 ± 0.007 | MAE: 0.616 ± 0.003

# %% [markdown]
# **Note:** In low-data regime (10% training data), Gaussian noise masking consistently outperforms both zero masking and supervised PatchTST across all horizons.
